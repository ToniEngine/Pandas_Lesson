# %% [markdown]
# # **Selecting Columns**

# %%
import pandas as pd
import numpy as np

# %%
df_csv = pd.read_csv("StudentsPerformance.csv")

# %%
df_csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# select a column with [] (preferred way to select a column)
df_csv['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df_csv['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_csv["gender"])
# Out:
# pandas.core.series.Series

# %%
# Series: attributes and methods
df_csv['math score'].dtype
# Out:
# dtype('int64')

# %%
df_csv["math score"].head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
df_csv["math score"].mean()
# Out:
# np.float64(66.089)

# %%
df_csv["math score"].shape
# Out:
# (1000,)

# %%
df_csv["math score"].head()
df_csv["math score"].mean()
df_csv["math score"].std()
df_csv["math score"].max()
df_csv["math score"].min()
df_csv["math score"].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
# select a column with dot notation
df_csv.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with dot notation (pitfalls)
# df_csv.math score
# SyntaxError: invalid syntax
# This happens because of the space in the column name
# To avoid this, we should use the [] notation
# df_csv.math_score  # This will work if the column name has no spaces

# %% [markdown]
# # Selecting Two or More Columns from a DataFrame

# %%
# selecting 2 columns using [[]]
df_csv[["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_csv[["gender", "math score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_csv[["math score", "reading score", "writing score", "gender"]]
# Out:
#      math score  reading score  writing score  gender
# 0            72             72             74  female
# 1            69             90             88  female
# 2            90             95             93  female
# 3            47             57             44    male
# 4            76             78             75    male
# ..          ...            ...            ...     ...
# 995          88             99             95  female
# 996          62             55             55    male
# 997          59             71             65  female
# 998          68             78             77  female
# 999          77             86             86  female
#
# [1000 rows x 4 columns]

# %%
# Adding New Column to DataFrame

# adding a new column with a scalar value

df_csv["New Column"] = 100
df_csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    New Column
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100

# %%
# Adding a new column with  an array
language_score = np.arange(0,1000)
# len(np.arange(0,1000))

# %%
df_csv["language score"] = language_score
df_csv
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      New Column  language score
# 0           100               0
# 1           100               1
# 2           100               2
# 3           100               3
# 4           100               4
# ..          ...             ...
# 995         100             995
# 996         100             996
# 997         100             997
# 998         100             998
# 999         100             999
#
# [1000 rows x 10 columns]

# %%
np.random.randint(1,100, size=1000)
# Out:
# array([16, 67, 39, 53, 42, 66, 63, 66, 13, 95, 83, 52, 15, 86, 28, 42,  5,
#        36,  3, 56, 65, 40, 97, 84, 99, 57, 69, 29, 11, 95, 58, 22,  1, 20,
#         1, 17, 47, 96, 87,  6, 54, 63, 95, 31, 57, 87, 30, 81, 65, 69, 32,
#        81, 28, 16, 38, 67, 43, 78, 63, 19, 27, 74, 97, 57,  8, 36, 40, 88,
#        37, 99,  5, 60, 84, 90, 41,  9, 96, 20, 87, 92, 61, 85, 92, 65, 26,
#         2, 79, 49,  2, 39, 20, 54, 92, 48, 13, 18, 92, 11, 42, 18, 71, 82,
#        55, 24, 64, 56, 59, 13, 53, 63,  3, 56, 98, 97, 12, 72, 59,  6, 75,
#        92, 59, 83, 97, 38, 46,  7, 38, 54, 31, 21, 45, 74, 26,  2, 31, 15,
#        59, 31, 23, 71, 47, 37, 18, 61, 30,  2, 27, 22, 35, 51, 42, 29, 67,
#        41, 22, 71, 13, 83,  9, 13, 36, 41, 89, 83, 44, 82, 37, 24, 13, 36,
#         7, 49, 68, 39, 62, 19, 85, 50, 28, 88,  3, 10, 79, 22, 77, 16, 44,
#        56, 68, 56, 62, 88, 92, 48,  8, 25, 31, 35, 17, 27,  9, 54, 72, 67,
#        18, 56, 72,  8, 92, 61,  1, 75,  1, 19, 42, 98, 55, 85, 42,  3, 69,
#        81, 81, 85, 38, 94, 84, 77, 82, 34, 20,  7, 98, 11,  4, 94, 94, 71,
#        44, 70, 92, 21, 64, 75, 41, 79,  5,  2, 43,  9,  8, 25, 23, 89, 52,
#        34, 65, 92, 91, 68, 69, 24, 19, 78, 22, 44, 71, 49, 42, 92,  2, 18,
#        78, 30, 49, 14, 51, 68, 90, 46, 82, 72, 59, 46,  4, 93, 60, 79, 47,
#        67, 62, 45, 96, 24,  2, 46,  5, 22, 30, 45, 47,  1, 91, 80, 72, 54,
#        32, 49,  2, 70, 70, 71, 95, 76, 50, 12, 91, 55, 36, 33, 40, 44, 93,
#        25, 17, 60, 67, 22, 82, 65, 43, 78, 80, 69, 19, 74, 78, 44, 83, 60,
#        82, 14, 96, 91, 36, 85, 17, 35, 30, 50, 84, 59, 74, 21,  5, 38, 27,
#        58, 81, 99, 45, 78, 26, 26, 47,  6, 63,  2, 14, 24, 56, 11, 52, 96,
#        76, 17, 65, 80, 98, 93, 54, 70,  4, 48, 44,  1, 82, 74, 25, 12, 48,
#        11, 81, 83, 89, 22, 30, 20, 72, 83, 23, 63, 92, 54, 18,  3, 48, 51,
#        36, 12, 10,  3, 29, 33, 73, 70, 93, 26, 10,  8, 75, 48, 49, 82, 99,
#        97, 72, 49,  2, 69, 60, 69, 91, 41, 93, 55,  2, 77, 80, 99, 80, 51,
#        48, 53, 34, 99, 95, 74, 39, 82, 20, 14, 73, 60, 75, 69,  3, 16, 64,
#        41, 75, 52, 27, 58, 71, 47, 26, 98, 55, 67, 43, 38, 53],
#       dtype=int32)

# %%
int_language_score = np.random.randint(1,101, size=1000)
max(int_language_score)
# Out:
# np.int32(100)

# %%
df_csv["New Language Score"] = int_language_score
df_csv
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      New Column  language score  New Language Score
# 0           100               0                   7
# 1           100               1                  30
# 2           100               2                  36
# 3           100               3                  55
# 4           100               4                  43
# ..          ...             ...                 ...
# 995         100             995                  32
# 996         100             996                  50
# 997         100             997                  43
# 998         100             998                  28
# 999         100             999                  41
#
# [1000 rows x 11 columns]

# %%
# creating random float numbers
np.random.uniform(1, 100, size=1000)
# Out:
# array([70.54563001, 90.25139917, 34.08359501, 93.50307509, 13.78907218,
#         7.83284434, 93.79271673, 60.00879396,  7.71287845, 31.91757057,
#        28.73118421, 19.6424438 , 93.0417317 , 52.37951731, 76.23904452,
#        98.48108325, 92.21042229, 93.19390299, 37.08507101, 19.04384738,
#        76.60064984, 95.74983232, 91.02069569, 94.54613055, 15.31402946,
#        17.59146454, 37.00128577, 49.27034919, 64.24746554, 97.32019987,
#        39.57749442, 90.66222856, 13.26702122, 61.14701741, 91.3033998 ,
#        85.09465013, 13.75773402, 39.04940558, 57.99575727, 30.96137658,
#        75.51404679, 15.29799812,  2.54287657, 33.93817206, 94.56330204,
#        92.80018625, 46.03207664, 58.47551998, 98.22164809, 89.46585627,
#        51.62303586, 48.42216224, 81.743917  , 73.35498307, 42.10380269,
#        87.44955171, 67.43871372, 81.82254225,  7.66735759, 45.3651531 ,
#        16.76070037, 17.49469226, 96.42367324, 99.78078755, 50.18479955,
#        33.65291368, 86.40695966, 79.73024953, 18.31585462, 40.14210558,
#        64.6337578 , 54.15413015, 38.40523972, 36.04502747, 35.2687106 ,
#        92.84657936, 61.41612123, 40.83932972, 88.24536289, 86.31547172,
#        17.32583602, 21.7306975 , 43.01988538, 57.08143776, 99.31540338,
#        38.70366738, 95.9479442 , 61.7030708 , 80.67358444, 66.04326274,
#        66.23756154, 98.1864309 , 11.94810199, 71.78095791, 59.69594289,
#        19.562349  , 15.0351257 , 37.20114427, 28.73110822, 81.81720411,
#        76.31410162, 25.39313623, 41.06481508, 28.50029997, 72.99087573,
#        10.58881165, 94.56638721, 35.99039562,  2.09315335, 98.70838961,
#        43.5559035 , 87.81012347, 23.52086228, 51.54910911, 79.34111571,
#        26.63778895, 13.08326681, 25.12368873, 58.23330241,  6.56132987,
#        79.73104195, 79.33187974, 78.88246265, 29.69310772, 80.99863494,
#        81.35568033, 37.23020603, 89.33694941, 87.03111842, 52.49030027,
#         2.08501493, 71.1393577 , 86.7162957 , 55.79200891, 90.52553914,
#        22.33027126, 39.06118484, 50.16854681, 10.17779863, 59.6848779 ,
#        84.08103205,  7.11805978, 76.31431993, 43.52489629, 98.54171347,
#        42.64111865, 51.60822438, 62.55450046, 32.11054301, 94.88762683])

# %%
# Assign a new column using assign() and insert() methods
# You use the assign method when you want to add multiple columns at once
# You use the insert method when you want to add a column at a specific position
# What of we do not declare the size? 
# It will throw an error because the length of the new column must match the length of the DataFrame

# df_csv = df_csv.assign(
#     science_score = np.random.randint(1,101, size=1000),
#     social_studies_score = np.random.randint(1,101, size=1000)
# )

# df_csv.head()

# %% [markdown]
#  # When to use assign

# %% [markdown]
# . Add multiple columns in a single line of code
#
#
# . When you need to overwrite the values of an existing columns(best practice)
#
#
# It returns a new object(a copy) with all the original columns in addition to the new ones

# %%
score1 = np.random.randint(1,100, size =1000)
score2 = np.random.randint(1,100, size =1000)

# %%
series1 = pd.Series(score1, index = np.arange(0,1000))
series2 = pd.Series(score2, index = np.arange(0,1000))

# %%
# using assign method to add multiple columns
df_csv.assign(score1 = series1, score2 = series2)
df_csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    New Column  language score  New Language Score
# 0         100               0                   7
# 1         100               1                  30
# 2         100               2                  36
# 3         100               3                  55
# 4         100               4                  43
